# %%
# !pip install openai-agents openai -q

# %%
# !pip install openai-agents -q
# !pip install openai -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.4/100.4 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.6 MB/s eta 0:00:00

# %%
import os
import openai

from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %%
from agents import Agent, Runner
import asyncio

# Define the Task Generator agent
task_generator = Agent(
    name="Task Generator",
    instructions="""You help users break down their specific LLM powered AI Agent goal into small, achievable tasks.
    For any goal, analyze it and create a structured plan with specific actionable steps.
    Each task should be concrete, time-bound when possible, and manageable.
    Organize tasks in a logical sequence with dependencies clearly marked.
    Never answer anything unrelated to AI Agents.""",
)

# Define a function to run the agent
async def generate_tasks(goal):
    result = await Runner.run(task_generator, goal)
    return result.final_output

# %%
# Example usage
async def main():
    user_goal = "I want to make an AI Agent that takes pictures of trees and displays information about them such as origin and family."
    tasks = await generate_tasks(user_goal)
    print(tasks)

# 3. Output the agent's answer
await main()
# Out:
# Creating an AI Agent that takes pictures of trees and provides information about them is a multi-step project. Here's a structured plan to achieve this goal:
#
# ### Phase 1: Research and Planning
#
# 1. **Define Objectives and Requirements**
#    - Time: 1 day
#    - Detail the functionalities you want in the AI Agent (e.g., type of information, user interface).
#    - Research existing technologies and solutions.
#
# 2. **Select Tools and Technologies**
#    - Time: 2 days
#    - Choose a platform (mobile app, web app, etc.).
#    - Decide on image recognition libraries (e.g., TensorFlow, PyTorch).
#    - Explore databases for botanical information.
#
# ### Phase 2: Data Collection and Preparation
#
# 3. **Collect Image Datasets**
#    - Time: 1 week
#    - Gather a dataset of tree images with labeled species.
#    - Ensure datasets cover a wide variety of trees and conditions.
#
# 4. **Prepare Botanical Information Database**
#    - Time: 3 days
#    - Compile a database of tree species, origins, and families.
#    - Ensure data is in a format easily accessible by the AI.
#
# ### Phase 3: AI Model Development
#
# 5. **Develop Image Recognition Model**
#    - Time: 2 weeks
#    - Train a model to identify tree species from images.
#    - Use transfer learning with pre-trained models as a start.
#
# 6. **Validate and Optimize Model**
#    - Time: 1 week
#    - Test the model with a separate validation set.
#    - Optimize for accuracy and performance.
#
# ### Phase 4: Application Development
#
# 7. **Design User Interface**
#    - Time: 1 week
#    - Create wireframes and design the user interface.
#    - Focus on usability and clarity.
#
# 8. **Integrate AI Model with Application**
#    - Time: 1 week
#    - Develop the application, integrating the image recognition model and information display.
#    - Ensure the application can take photos, process them, and display data.
#
# ### Phase 5: Testing and Deployment
#
# 9. **Conduct User Testing**
#    - Time: 1 week
#    - Test the application with real users to gather feedback.
#    - Make necessary adjustments based on feedback.
#
# 10. **Finalize and Deploy**
#     - Time: 3 days
#     - Fix any issues uncovered during testing.
#     - Deploy the application to the chosen platform.
#
# ### Phase 6: Maintenance and Updates
#
# 11. **Monitor and Update**
#     - Ongoing
#     - Continuously improve the model with new data.
#     - Implement updates based on user feedback and technological advancements.
#
# Following these steps will help you systematically build a functional AI Agent for tree identification and information display.
